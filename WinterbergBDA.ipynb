# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/Users/said.ch/Desktop/data/10012021_4man/"
alleDateien = glob.glob(os.path.join(path,"*.csv"))

# %%
df_new = pd.DataFrame(data,columns=[''])

i = 0
for datei in alleDateien:
    i = i + 1
    df = pd.read_csv(datei,index_col=None, header=0)
    time_new = df["Time s"]
    dist_new = df[" Distance m"]
    spieler = 'Spieler' + str(i) + 'Time' #+ str(i)
    df_new[spieler] =  time_new
    spieler = 'Spieler' + str(i) + 'Dist' #+ str(i)
    df_new[spieler] =  dist_new
    for ind in df.index:
        v = df[" Distance m"][ind] / df["Time s"][ind]
        

print(i)
df_new = df_new.fillna(0)
df_new.drop(df_new.columns[[0]], axis=1, inplace=True)
# Out:
# /var/folders/t6/x5w_6q8x6k59x2264h3pbk9c0000gn/T/ipykernel_1859/2502120699.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#   v = df[" Distance m"][ind] / df["Time s"][ind]
# 31

# %%
df_new
# Out:
#       Spieler1Time  Spieler1Dist  Spieler2Time  Spieler2Dist  Spieler3Time  \
# 0           -4.999 -9.278534e-22        -4.994  6.222642e-25        -4.994
# 1           -4.989 -9.857159e-22        -4.984  6.989987e-25        -4.984
# 2           -4.979 -1.050149e-21        -4.974  7.948088e-25        -4.974
# 3           -4.969 -1.119342e-21        -4.964  9.206131e-25        -4.964
# 4           -4.959 -1.189278e-21        -4.954  1.086159e-24        -4.954
# ...            ...           ...           ...           ...           ...
# 7488        69.881  1.557300e+03         0.000  0.000000e+00         0.000
# 7489        69.891  1.557300e+03         0.000  0.000000e+00         0.000
# 7490        69.901  1.557300e+03         0.000  0.000000e+00         0.000
# 7491        69.911  1.557300e+03         0.000  0.000000e+00         0.000
# 7492        69.921  1.557300e+03         0.000  0.000000e+00         0.000
#
#       Spieler3Dist  Spieler4Time  Spieler4Dist  Spieler5Time  Spieler5Dist  \
# 0    -9.042608e-24        -4.995 -1.567004e-20        -4.991 -1.769429e-21
# 1    -9.124042e-24        -4.985 -1.380303e-20        -4.981 -2.048411e-21
# 2    -8.393673e-24        -4.975 -1.201184e-20        -4.971 -2.373096e-21
# 3    -6.531883e-24        -4.965 -1.037078e-20        -4.961 -2.752551e-21
# 4    -3.214246e-24        -4.955 -8.928823e-21        -4.951 -3.205496e-21
# ...            ...           ...           ...           ...           ...
# 7488  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7489  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7490  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7491  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7492  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
#
#       ...  Spieler27Time  Spieler27Dist  Spieler28Time  Spieler28Dist  \
# 0     ...         -4.995   4.232225e-23         -4.995   5.166181e-23
# 1     ...         -4.985   4.891156e-23         -4.985   6.184879e-23
# 2     ...         -4.975   5.739279e-23         -4.975   7.173675e-23
# 3     ...         -4.965   6.895817e-23         -4.965   8.127428e-23
# 4     ...         -4.955   8.472021e-23         -4.955   9.090493e-23
# ...   ...            ...            ...            ...            ...
# 7488  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7489  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7490  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7491  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7492  ...          0.000   0.000000e+00          0.000   0.000000e+00
#
#       Spieler29Time  Spieler29Dist  Spieler30Time  Spieler30Dist  \
# 0            -4.999   2.487065e-23         -4.995   3.067910e-22
# 1            -4.989   3.313255e-23         -4.985   3.209399e-22
# 2            -4.979   3.962716e-23         -4.975   3.358493e-22
# 3            -4.969   4.520999e-23         -4.965   3.522988e-22
# 4            -4.959   5.207357e-23         -4.955   3.710008e-22
# ...             ...            ...            ...            ...
# 7488          0.000   0.000000e+00          0.000   0.000000e+00
# 7489          0.000   0.000000e+00          0.000   0.000000e+00
# 7490          0.000   0.000000e+00          0.000   0.000000e+00
# 7491          0.000   0.000000e+00          0.000   0.000000e+00
# 7492          0.000   0.000000e+00          0.000   0.000000e+00
#
#       Spieler31Time  Spieler31Dist
# 0            -4.997   2.146399e-22
# 1            -4.987   2.056640e-22
# 2            -4.977   1.906804e-22
# 3            -4.967   1.612301e-22
# 4            -4.957   1.042986e-22
# ...             ...            ...
# 7488          0.000   0.000000e+00
# 7489          0.000   0.000000e+00
# 7490          0.000   0.000000e+00
# 7491          0.000   0.000000e+00
# 7492          0.000   0.000000e+00
#
# [7493 rows x 62 columns]

# %%
#Test Zweck
df_new.head()
x = df_new["Spieler1Time"]
y = df_new["Spieler1Dist"]
plt.plot(x, y, 'r--')
plt.xlabel('X Spieler1 Time')
plt.ylabel('Y Spieler1 Dist')
plt.title('Spieler 1')
# Out:
# Text(0.5, 1.0, 'Spieler 1')

# %%
df_new
# Out:
#       Spieler1Time  Spieler1Dist  Spieler2Time  Spieler2Dist  Spieler3Time  \
# 0           -4.999 -9.278534e-22        -4.994  6.222642e-25        -4.994
# 1           -4.989 -9.857159e-22        -4.984  6.989987e-25        -4.984
# 2           -4.979 -1.050149e-21        -4.974  7.948088e-25        -4.974
# 3           -4.969 -1.119342e-21        -4.964  9.206131e-25        -4.964
# 4           -4.959 -1.189278e-21        -4.954  1.086159e-24        -4.954
# ...            ...           ...           ...           ...           ...
# 7488        69.881  1.557300e+03         0.000  0.000000e+00         0.000
# 7489        69.891  1.557300e+03         0.000  0.000000e+00         0.000
# 7490        69.901  1.557300e+03         0.000  0.000000e+00         0.000
# 7491        69.911  1.557300e+03         0.000  0.000000e+00         0.000
# 7492        69.921  1.557300e+03         0.000  0.000000e+00         0.000
#
#       Spieler3Dist  Spieler4Time  Spieler4Dist  Spieler5Time  Spieler5Dist  \
# 0    -9.042608e-24        -4.995 -1.567004e-20        -4.991 -1.769429e-21
# 1    -9.124042e-24        -4.985 -1.380303e-20        -4.981 -2.048411e-21
# 2    -8.393673e-24        -4.975 -1.201184e-20        -4.971 -2.373096e-21
# 3    -6.531883e-24        -4.965 -1.037078e-20        -4.961 -2.752551e-21
# 4    -3.214246e-24        -4.955 -8.928823e-21        -4.951 -3.205496e-21
# ...            ...           ...           ...           ...           ...
# 7488  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7489  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7490  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7491  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
# 7492  0.000000e+00         0.000  0.000000e+00         0.000  0.000000e+00
#
#       ...  Spieler27Time  Spieler27Dist  Spieler28Time  Spieler28Dist  \
# 0     ...         -4.995   4.232225e-23         -4.995   5.166181e-23
# 1     ...         -4.985   4.891156e-23         -4.985   6.184879e-23
# 2     ...         -4.975   5.739279e-23         -4.975   7.173675e-23
# 3     ...         -4.965   6.895817e-23         -4.965   8.127428e-23
# 4     ...         -4.955   8.472021e-23         -4.955   9.090493e-23
# ...   ...            ...            ...            ...            ...
# 7488  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7489  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7490  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7491  ...          0.000   0.000000e+00          0.000   0.000000e+00
# 7492  ...          0.000   0.000000e+00          0.000   0.000000e+00
#
#       Spieler29Time  Spieler29Dist  Spieler30Time  Spieler30Dist  \
# 0            -4.999   2.487065e-23         -4.995   3.067910e-22
# 1            -4.989   3.313255e-23         -4.985   3.209399e-22
# 2            -4.979   3.962716e-23         -4.975   3.358493e-22
# 3            -4.969   4.520999e-23         -4.965   3.522988e-22
# 4            -4.959   5.207357e-23         -4.955   3.710008e-22
# ...             ...            ...            ...            ...
# 7488          0.000   0.000000e+00          0.000   0.000000e+00
# 7489          0.000   0.000000e+00          0.000   0.000000e+00
# 7490          0.000   0.000000e+00          0.000   0.000000e+00
# 7491          0.000   0.000000e+00          0.000   0.000000e+00
# 7492          0.000   0.000000e+00          0.000   0.000000e+00
#
#       Spieler31Time  Spieler31Dist
# 0            -4.997   2.146399e-22
# 1            -4.987   2.056640e-22
# 2            -4.977   1.906804e-22
# 3            -4.967   1.612301e-22
# 4            -4.957   1.042986e-22
# ...             ...            ...
# 7488          0.000   0.000000e+00
# 7489          0.000   0.000000e+00
# 7490          0.000   0.000000e+00
# 7491          0.000   0.000000e+00
# 7492          0.000   0.000000e+00
#
# [7493 rows x 62 columns]

# %%
for ind in df.index:
     print(df['Name'][ind], df['Stream'][ind])
